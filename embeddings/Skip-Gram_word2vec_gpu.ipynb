# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:21, 385KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# # Your code here
# def subsampling(words, threshold):
#     word_freqs = Counter(words)
#     return [k for k in words if word_freqs[k] > threshold]
        
# train_words = subsampling(int_words, 10000)# The final subsampled word list

# %%
print(len(train_words))
# Out:
# 4627334

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(window_size) + 1
    if idx < r:
        r = idx
    return words[idx - r:idx] + words[idx + 1:idx + r + 1]

# %%
print(get_target(train_words, 4, 5))
# Out:
# [3134, 476, 10605, 15070, 58381, 3582]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
a = get_batches(train_words, 10, 3)
print(np.array(a.__next__()[1])[:,None])
# Out:
# [[ 5235]
#  [  476]
#  [ 5235]
#  [ 3134]
#  [10605]
#  [27440]
#  [ 3134]
#  [  476]
#  [27440]
#  [15070]
#  [ 3134]
#  [  476]
#  [10605]
#  [15070]
#  [58381]
#  [ 3582]
#  [27440]
#  [58381]
#  [15070]
#  [ 3582]
#  [15070]
#  [58381]
#  [  194]
#  [10724]
#  [58381]
#  [ 3582]
#  [10724]
#  [ 3582]
#  [  194]]

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_normal([n_vocab, n_embedding]))# create softmax weight matrix here
    softmax_b = tf.zeros(n_vocab)# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      labels=labels,
                                      inputs=embed,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab,
                                      partition_strategy="div"
                                     )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 20.1638 0.0790 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 19.9024 0.0736 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 19.6027 0.0734 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 19.6186 0.0738 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 19.3465 0.0734 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 19.2787 0.0743 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 19.1613 0.0734 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 19.0275 0.0732 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 18.8122 0.0737 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 18.7434 0.0731 sec/batch
# Nearest to seven: straining, anaheim, catoctin, abergavenny, hopewell, leaded, procured, heligoland,
# Nearest to war: trams, obligated, miracle, stoa, patient, electrolyte, pdpa, finding,
# Nearest to so: kamikazes, pong, leon, gavrilo, individualist, boggy, ligamentum, aau,
# Nearest to s: akston, stavropol, ascension, atum, magadha, hmso, folktales, whatsoever,
# Nearest to there: dari, swords, disk, appeasement, compressibility, mathbf, misunderstanding, javan,
# Nearest to were: extensively, coworkers, criminally, declarations, lopsided, slots, variational, inflections,
# Nearest to first: miasto, charities, crandall, carrion, portraits, amanullah, schemas, doppler,
# Nearest to will: magi, quenya, carboxylate, departures, undesired, lhd, impermanent, anodic,
# Nearest to road: forfeits, socialism, morph, narrowband, legitimize, desires, daltrey, baasha,
# Nearest to test: residence, invincibility, aquarii, lactantius, taunts, controls, otranto, bedrock,
# Nearest to woman: sharman, slalom, generated, scent, drum, momentarily, latour, e,
# Nearest to ocean: registries, judaea, bumping, flower, ussher, senile, distorting, torii,
# Nearest to arts: mandibles, seeking, saunderson, overblown, menu, orbison, receptors, jizya,
# Nearest to except: uefa, satya, caliphates, rsx, stature, archaic, kyrgyz, aerated,
# Nearest to engine: cancer, updated, dba, suspend, melting, velde, bambi, lumbering,
# Nearest to mean: bal, invokes, sura, exceptional, amounting, attacked, hohenstaufen, buttstock,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 18.6611 0.0742 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 18.4483 0.0735 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 18.4131 0.0736 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 18.2013 0.0738 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 18.1429 0.0738 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 18.0703 0.0728 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 17.8543 0.0731 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 17.7226 0.0742 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 17.5611 0.0733 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 17.4942 0.0731 sec/batch
# Nearest to seven: straining, anaheim, leaded, hopewell, abergavenny, procured, heligoland, catoctin,
# Nearest to war: obligated, trams, stoa, themas, patient, miracle, rabbits, electrolyte,
# Nearest to so: kamikazes, pong, ligamentum, leon, individualist, gavrilo, cornholio, boggy,
# Nearest to s: akston, stavropol, ascension, folktales, magadha, dunfermline, atum, lunda,
# Nearest to there: dari, disk, compressibility, swords, appeasement, misunderstanding, mathbf, lunisolar,
# Nearest to were: extensively, coworkers, declarations, slots, criminally, lopsided, inflections, variational,
# Nearest to first: miasto, charities, portraits, carrion, amanullah, pelt, assisting, crandall,
# Nearest to will: magi, quenya, carboxylate, departures, undesired, impermanent, anodic, lhd,
# Nearest to road: forfeits, socialism, morph, desires, cosmos, cdp, baasha, narrowband,
# Nearest to test: residence, aquarii, invincibility, bedrock, controls, lactantius, taunts, decode,
# Nearest to woman: drum, generated, sharman, slalom, scent, momentarily, propositions, latent,
# Nearest to ocean: registries, judaea, flower, bumping, ussher, senile, torii, monogamy,
# Nearest to arts: receptors, jizya, mandibles, orbison, saunderson, overblown, vied, seeking,
# Nearest to except: uefa, satya, caliphates, stature, rsx, archaic, friedman, aerated,
# Nearest to engine: cancer, updated, dba, melting, suspend, velde, lumbering, bambi,
# Nearest to mean: bal, invokes, sura, amounting, attacked, hohenstaufen, exceptional, fahd,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 17.3226 0.0753 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 17.2290 0.0736 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 17.2169 0.0735 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 17.1028 0.0740 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 16.9758 0.0737 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 16.8390 0.0738 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 16.7663 0.0735 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 16.6788 0.0738 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 16.6032 0.0744 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 16.4283 0.0734 sec/batch
# Nearest to seven: straining, anaheim, leaded, hopewell, heligoland, procured, catoctin, abergavenny,
# Nearest to war: obligated, trams, stoa, themas, miracle, patient, rabbits, pdpa,
# Nearest to so: kamikazes, pong, leon, insist, ligamentum, saving, individualist, badges,
# Nearest to s: akston, stavropol, folktales, dunfermline, ascension, mollified, hmso, magadha,
# Nearest to there: dari, swords, compressibility, disk, appeasement, ceylon, mathbf, lunisolar,
# Nearest to were: extensively, declarations, coworkers, criminally, slots, lopsided, inflections, survival,
# Nearest to first: miasto, portraits, doppler, charities, amanullah, crandall, schemas, carrion,
# Nearest to will: magi, quenya, carboxylate, undesired, departures, impermanent, malevich, lhd,
# Nearest to road: forfeits, socialism, morph, desires, cosmos, cdp, baasha, narrowband,
# Nearest to test: residence, aquarii, invincibility, bedrock, decode, lactantius, otranto, taunts,
# Nearest to woman: drum, scent, sharman, slalom, momentarily, propositions, latour, generated,
# Nearest to ocean: registries, judaea, bumping, flower, senile, ussher, torii, ailing,
# Nearest to arts: mandibles, jizya, vied, overblown, saunderson, proceeded, vehicles, receptors,
# Nearest to except: uefa, satya, stature, caliphates, friedman, rsx, kyrgyz, archaic,
# Nearest to engine: cancer, updated, dba, melting, suspend, velde, lumbering, bambi,
# Nearest to mean: bal, invokes, amounting, sura, hohenstaufen, rafter, parte, exceptional,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 16.3621 0.0744 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 16.3029 0.0737 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 16.0920 0.0742 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 16.0483 0.0735 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 15.9746 0.0743 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 15.8742 0.0743 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 15.7880 0.0739 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 15.7106 0.0734 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 15.5175 0.0735 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 15.5232 0.0744 sec/batch
# Nearest to seven: sometimes, leaded, anaheim, serialized, straining, programs, heligoland, pentecostal,
# Nearest to war: trams, obligated, themas, stoa, miracle, rabbits, patient, june,
# Nearest to so: pong, insist, saving, kamikazes, cellars, ligamentum, leon, emma,
# Nearest to s: whatsoever, akston, stavropol, dunfermline, folktales, broad, did, mollified,
# Nearest to there: dari, appeasement, compressibility, swords, disk, lunisolar, ceylon, pindar,
# Nearest to were: declarations, extensively, coworkers, slots, criminally, lopsided, inflections, frisians,
# Nearest to first: miasto, doppler, portraits, assisting, hejira, schemas, amanullah, crandall,
# Nearest to will: magi, quenya, undesired, carboxylate, malevich, departures, impermanent, anodic,
# Nearest to road: forfeits, socialism, morph, cdp, cosmos, jackal, annihilates, desires,
# Nearest to test: residence, aquarii, bedrock, invincibility, controls, lactantius, bond, decode,
# Nearest to woman: drum, slalom, scent, sharman, propositions, momentarily, pointe, latent,
# Nearest to ocean: registries, judaea, flower, bumping, arbitrio, ailing, senile, monogamy,
# Nearest to arts: proceeded, overblown, jizya, lodges, saunderson, coincidences, orbison, receptors,
# Nearest to except: uefa, caliphates, stature, satya, rsx, aerated, friedman, afips,
# Nearest to engine: cancer, updated, dba, melting, suspend, velde, detachment, lumbering,
# Nearest to mean: bal, invokes, hohenstaufen, amounting, yogi, parte, sura, exceptional,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 15.5361 0.0747 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 15.3283 0.0743 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 15.2029 0.0738 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 15.1601 0.0739 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 15.0989 0.0743 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 14.8728 0.0738 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 14.8289 0.0542 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 14.7621 0.0743 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 14.6820 0.0738 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 14.5235 0.0744 sec/batch
# Nearest to seven: serialized, leaded, programs, sometimes, deemphasized, unfree, anaheim, necromancy,
# Nearest to war: obligated, trams, patient, rabbits, themas, june, miracle, stoa,
# Nearest to so: saving, insist, pong, one, cellars, ligamentum, badges, emma,
# Nearest to s: did, retrieval, hmso, planners, folktales, bowlers, the, suggestibility,
# Nearest to there: dari, appeasement, swords, compressibility, lunisolar, ceylon, mathbf, disk,
# Nearest to were: declarations, extensively, slots, frisians, inflections, coworkers, lopsided, loyal,
# Nearest to first: doppler, assisting, portraits, crandall, byronic, in, agendas, schemas,
# Nearest to will: magi, quenya, carboxylate, undesired, anodic, allosteric, malevich, protesters,
# Nearest to road: forfeits, socialism, morph, cdp, cosmos, annihilates, jackal, bazin,
# Nearest to test: invincibility, residence, controls, bedrock, aquarii, otranto, conflagration, lactantius,
# Nearest to woman: drum, slalom, scent, momentarily, sharman, pointe, latour, generated,
# Nearest to ocean: judaea, registries, flower, bumping, ailing, monogamy, vii, ussher,
# Nearest to arts: proceeded, lodges, haben, jizya, saunderson, meg, receptors, halabja,
# Nearest to except: uefa, caliphates, stature, satya, rsx, aerated, friedman, afips,
# Nearest to engine: cancer, melting, dba, updated, suspend, velde, detachment, bambi,
# Nearest to mean: bal, invokes, hohenstaufen, parte, yogi, sura, exceptional, fahd,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 14.5063 0.0754 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 14.3830 0.0735 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 14.2369 0.0738 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 14.2893 0.0741 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 14.1557 0.0744 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 14.0880 0.0739 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 13.8889 0.0737 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 13.8066 0.0737 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 13.8216 0.0741 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 13.7486 0.0736 sec/batch
# Nearest to seven: one, two, for, in, five, and, from, of,
# Nearest to war: obligated, trams, deists, themas, rabbits, patient, miracle, opel,
# Nearest to so: one, saving, traveling, guildford, pong, cellars, dig, leon,
# Nearest to s: the, to, in, a, as, for, of, and,
# Nearest to there: dari, compressibility, appeasement, ceylon, swords, lunisolar, javan, disk,
# Nearest to were: declarations, frisians, embassies, implied, inflections, extensively, coworkers, intuitionist,
# Nearest to first: in, to, doppler, of, and, portraits, agendas, one,
# Nearest to will: magi, quenya, carboxylate, undesired, allosteric, hamlets, redirects, anodic,
# Nearest to road: forfeits, socialism, morph, cosmos, cdp, annihilates, narrowband, baasha,
# Nearest to test: bedrock, invincibility, conflagration, residence, otranto, controls, summed, aquarii,
# Nearest to woman: drum, slalom, scent, sharman, pointe, momentarily, latent, propositions,
# Nearest to ocean: judaea, registries, bumping, flower, ussher, monogamy, senile, ailing,
# Nearest to arts: proceeded, haben, lodges, meg, saunderson, jizya, receptors, tapu,
# Nearest to except: uefa, stature, rsx, caliphates, aerated, satya, malt, kyrgyz,
# Nearest to engine: cancer, melting, dba, updated, velde, suspend, detachment, ration,
# Nearest to mean: bal, invokes, parte, sura, hohenstaufen, exceptional, yogi, fahd,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 13.7077 0.0753 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 13.5681 0.0746 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 13.5233 0.0742 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 13.5090 0.0744 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 13.4278 0.0743 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 13.3276 0.0738 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 13.1701 0.0732 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 13.1771 0.0742 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 13.0934 0.0750 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 13.0041 0.0745 sec/batch
# Nearest to seven: one, two, nine, zero, six, in, five, the,
# Nearest to war: obligated, rabbits, themas, deists, to, dianne, opel, seven,
# Nearest to so: it, was, three, as, the, on, insist, in,
# Nearest to s: in, the, of, and, to, one, zero, for,
# Nearest to there: these, compressibility, dari, mathbf, from, that, appeasement, or,
# Nearest to were: and, the, of, with, to, on, in, also,
# Nearest to first: a, two, one, in, of, which, the, on,
# Nearest to will: allosteric, not, quenya, carboxylate, anodic, magi, undesired, riverine,
# Nearest to road: forfeits, socialism, morph, cosmos, annihilates, baasha, cdp, na,
# Nearest to test: invincibility, bedrock, conflagration, otranto, controls, aquarii, residence, ines,
# Nearest to woman: drum, slalom, scent, pointe, sharman, momentarily, propositions, latour,
# Nearest to ocean: judaea, bumping, registries, flower, ussher, senile, monogamy, ailing,
# Nearest to arts: proceeded, haben, saunderson, lodges, albi, hoods, halabja, moose,
# Nearest to except: stature, uefa, rsx, caliphates, satya, aerated, malt, kyrgyz,
# Nearest to engine: cancer, melting, dba, velde, updated, ration, atlantis, smiled,
# Nearest to mean: bal, invokes, parte, sura, yogi, exceptional, fahd, hohenstaufen,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 13.0583 0.0750 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 12.9233 0.0727 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 12.6218 0.0736 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 12.8053 0.0743 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 12.7715 0.0744 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 12.5640 0.0742 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 12.5657 0.0741 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 12.5563 0.0743 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 12.3782 0.0736 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 12.3099 0.0738 sec/batch
# Nearest to seven: one, three, six, eight, two, nine, zero, five,
# Nearest to war: seven, were, was, four, from, been, one, eight,
# Nearest to so: are, was, for, but, not, which, a, two,
# Nearest to s: to, in, the, of, and, a, that, zero,
# Nearest to there: a, or, this, these, to, for, it, in,
# Nearest to were: and, the, to, of, for, from, have, that,
# Nearest to first: of, from, to, in, on, and, an, the,
# Nearest to will: not, as, this, five, on, new, two, that,
# Nearest to road: forfeits, socialism, morph, cosmos, cdp, annihilates, maa, baasha,
# Nearest to test: controls, aquarii, bedrock, invincibility, otranto, bond, summed, ines,
# Nearest to woman: slalom, drum, scent, pointe, latour, sharman, airplane, momentarily,
# Nearest to ocean: registries, judaea, bumping, flower, ussher, les, ailing, propagated,
# Nearest to arts: proceeded, tapu, lodges, haben, saunderson, hoods, meg, overblown,
# Nearest to except: stature, caliphates, satya, rsx, kyrgyz, malt, uefa, lexicon,
# Nearest to engine: cancer, melting, updated, dba, velde, ration, atlantis, pda,
# Nearest to mean: bal, invokes, parte, exceptional, hohenstaufen, sura, joins, yogi,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 12.2127 0.0749 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 12.3795 0.0742 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 12.1429 0.0738 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 12.1649 0.0739 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 12.2029 0.0739 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 11.8255 0.0741 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 12.0818 0.0742 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 11.9059 0.0743 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 11.7184 0.0738 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 11.7405 0.0742 sec/batch
# Nearest to seven: one, nine, eight, three, six, five, four, two,
# Nearest to war: the, were, his, with, of, first, during, after,
# Nearest to so: in, the, is, who, this, as, some, of,
# Nearest to s: in, was, the, and, with, of, on, to,
# Nearest to there: for, a, to, is, with, that, it, this,
# Nearest to were: the, was, and, of, from, in, on, a,
# Nearest to first: the, in, of, was, to, and, on, were,
# Nearest to will: who, in, some, be, the, of, not, was,
# Nearest to road: forfeits, socialism, morph, cosmos, cdp, maa, baasha, bannockburn,
# Nearest to test: aquarii, bedrock, invincibility, bond, ines, biography, otranto, decode,
# Nearest to woman: slalom, drum, airplane, scent, pointe, sharman, siblings, latour,
# Nearest to ocean: bumping, judaea, ailing, registries, arbitrio, flower, ussher, les,
# Nearest to arts: halabja, moose, lodges, bettis, proceeded, meg, tapu, jizya,
# Nearest to except: stature, satya, malt, uefa, lexicon, caliphates, rsx, mentoring,
# Nearest to engine: cancer, updated, melting, dba, velde, ration, mindanao, atlantis,
# Nearest to mean: bal, invokes, parte, exceptional, joins, adventurers, hohenstaufen, ucayali,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 11.7411 0.0751 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 11.7025 0.0743 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 11.6004 0.0346 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 11.5132 0.0741 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 11.4849 0.0738 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 11.3969 0.0736 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 11.3505 0.0734 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 11.3491 0.0729 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 11.1975 0.0739 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 10.9960 0.0741 sec/batch
# Nearest to seven: one, nine, two, eight, four, three, six, zero,
# Nearest to war: the, of, in, his, were, was, to, after,
# Nearest to so: is, in, to, be, a, that, of, and,
# Nearest to s: and, of, a, in, the, to, on, by,
# Nearest to there: a, to, is, and, of, for, in, by,
# Nearest to were: in, the, and, of, a, from, was, by,
# Nearest to first: of, in, the, was, a, one, and, to,
# Nearest to will: in, to, this, a, from, and, may, was,
# Nearest to road: forfeits, morph, cdp, sign, socialism, rather, cosmos, maa,
# Nearest to test: biography, aquarii, ines, summed, otranto, bond, tolstoy, deception,
# Nearest to woman: slalom, read, drum, echidnas, mats, davidian, prison, airplane,
# Nearest to ocean: judaea, bumping, eye, level, flower, ailing, arbitrio, humphrey,
# Nearest to arts: halabja, jizya, moose, lodges, bettis, overblown, maka, affiliates,
# Nearest to except: some, also, result, not, are, however, stature, between,
# Nearest to engine: updated, cancer, dba, velde, melting, ration, pda, deputies,
# Nearest to mean: bal, invokes, exceptional, parte, timer, joins, adventurers, hohenstaufen,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 11.0738 0.0748 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 10.9966 0.0739 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 10.8800 0.0737 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 10.7074 0.0741 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 10.7427 0.0740 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 10.7342 0.0740 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 10.8326 0.0742 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 10.6951 0.0745 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 10.5489 0.0740 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 10.4579 0.0737 sec/batch
# Nearest to seven: eight, four, one, two, nine, six, zero, three,
# Nearest to war: the, later, a, one, during, also, of, in,
# Nearest to so: and, the, from, of, it, a, to, not,
# Nearest to s: the, one, zero, on, as, of, and, to,
# Nearest to there: in, and, the, it, a, of, from, with,
# Nearest to were: the, it, of, in, by, to, a, and,
# Nearest to first: the, of, was, for, and, were, one, s,
# Nearest to will: it, to, which, the, a, for, is, they,
# Nearest to road: began, man, forfeits, rather, th, came, western, eventually,
# Nearest to test: low, often, biography, aquarii, known, basis, ines, summed,
# Nearest to woman: passed, been, without, similar, around, like, were, read,
# Nearest to ocean: level, french, too, directly, large, no, world, said,
# Nearest to arts: moose, seeking, triangle, variables, halabja, jizya, cervical, modules,
# Nearest to except: between, last, back, some, take, with, result, this,
# Nearest to engine: updated, cancer, dba, velde, lived, ration, melting, deputies,
# Nearest to mean: wrote, bal, believe, meaning, turn, past, created, introduced,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 10.5241 0.0751 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 10.4984 0.0736 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 10.1809 0.0734 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 10.2831 0.0742 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 10.3159 0.0744 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 10.1313 0.0740 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 10.1650 0.0739 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 10.2886 0.0737 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 9.7622 0.0740 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 10.0074 0.0734 sec/batch
# Nearest to seven: eight, nine, six, one, two, zero, five, four,
# Nearest to war: of, during, to, one, the, s, from, in,
# Nearest to so: the, of, it, as, a, in, with, have,
# Nearest to s: the, in, and, of, two, to, zero, one,
# Nearest to there: the, of, that, is, with, to, a, has,
# Nearest to were: the, to, was, of, in, as, a, during,
# Nearest to first: of, and, the, in, a, s, to, from,
# Nearest to will: to, the, can, and, as, in, would, when,
# Nearest to road: man, little, later, largest, united, rather, down, back,
# Nearest to test: low, different, basis, takes, fact, while, such, known,
# Nearest to woman: which, been, such, he, who, further, would, up,
# Nearest to ocean: french, level, which, its, held, attempts, him, four,
# Nearest to arts: halabja, moose, cervical, variables, absolute, seeking, jizya, modules,
# Nearest to except: of, because, has, well, second, large, the, result,
# Nearest to engine: lower, velde, updated, game, cancer, rd, october, find,
# Nearest to mean: wrote, u, where, introduced, s, second, often, meaning,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 10.0650 0.0751 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 9.8167 0.0742 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 9.8001 0.0742 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 9.7873 0.0742 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 9.6874 0.0737 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 9.6076 0.0741 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 9.5367 0.0745 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 9.7460 0.0741 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 9.5820 0.0743 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 9.5167 0.0736 sec/batch
# Nearest to seven: one, eight, four, nine, two, three, six, five,
# Nearest to war: of, in, during, the, and, state, new, under,
# Nearest to so: to, a, this, be, they, and, that, used,
# Nearest to s: the, in, of, was, to, and, first, as,
# Nearest to there: have, not, has, this, of, a, an, is,
# Nearest to were: of, the, to, by, as, and, on, was,
# Nearest to first: the, in, of, a, and, was, on, s,
# Nearest to will: a, that, can, an, or, not, this, is,
# Nearest to road: particularly, began, man, program, two, on, home, center,
# Nearest to test: terms, particular, low, claims, different, basis, recent, typically,
# Nearest to woman: known, which, of, it, up, links, who, they,
# Nearest to ocean: south, french, sea, full, north, land, level, country,
# Nearest to arts: absolute, much, prevented, entry, maintained, results, source, graduates,
# Nearest to except: called, if, or, is, are, however, can, has,
# Nearest to engine: lower, game, rd, cancer, march, while, lived, this,
# Nearest to mean: almost, face, name, like, produce, introduced, children, back,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 9.7417 0.0743 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 9.2141 0.0736 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 9.5477 0.0740 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 9.3690 0.0736 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 9.1466 0.0732 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 9.3028 0.0741 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 9.2426 0.0739 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 9.1517 0.0740 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 9.1778 0.0147 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 8.9688 0.0741 sec/batch
# Nearest to seven: eight, four, one, nine, five, six, three, two,
# Nearest to war: the, of, was, began, at, in, s, during,
# Nearest to so: that, to, in, be, is, have, it, of,
# Nearest to s: a, of, in, was, the, and, by, to,
# Nearest to there: to, is, of, and, in, the, such, that,
# Nearest to were: of, to, s, the, and, a, in, was,
# Nearest to first: was, the, in, and, by, of, had, with,
# Nearest to will: that, a, this, be, to, have, in, only,
# Nearest to road: man, had, having, first, once, eight, when, october,
# Nearest to test: terms, basis, defined, contain, example, claims, complex, most,
# Nearest to woman: life, to, at, death, with, the, was, zero,
# Nearest to ocean: country, south, north, sea, near, western, over, government,
# Nearest to arts: needed, older, much, changed, several, however, further, without,
# Nearest to except: there, the, to, be, of, same, is, in,
# Nearest to engine: find, kind, game, probably, will, she, respect, example,
# Nearest to mean: almost, a, is, with, be, also, s, due,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 9.1108 0.0755 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 9.0718 0.0742 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 8.8754 0.0742 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 9.0427 0.0734 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 8.7711 0.0734 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 8.6711 0.0732 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 8.7226 0.0731 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 8.7898 0.0735 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 8.6781 0.0736 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 8.3163 0.0734 sec/batch
# Nearest to seven: eight, one, four, five, six, nine, zero, three,
# Nearest to war: world, during, took, s, the, were, was, in,
# Nearest to so: all, as, it, a, to, with, not, the,
# Nearest to s: the, in, and, of, at, to, from, a,
# Nearest to there: of, and, is, for, the, in, to, a,
# Nearest to were: the, of, for, s, to, and, in, was,
# Nearest to first: the, in, one, of, s, by, to, from,
# Nearest to will: be, this, a, or, is, which, not, may,
# Nearest to road: few, center, received, later, seven, one, his, while,
# Nearest to test: of, up, is, making, or, like, be, between,
# Nearest to woman: an, well, out, great, two, words, other, many,
# Nearest to ocean: south, sea, north, central, country, january, region, cities,
# Nearest to arts: much, entirely, source, coming, provided, several, maintained, original,
# Nearest to except: is, from, in, as, by, to, there, not,
# Nearest to engine: kind, examples, ends, note, simply, example, less, respect,
# Nearest to mean: is, with, be, take, use, sometimes, like, can,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 8.4501 0.0749 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 8.4171 0.0748 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 8.6311 0.0733 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 8.6166 0.0755 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 8.3269 0.0742 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 8.4190 0.0738 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 8.3957 0.0741 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 8.5057 0.0734 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 8.0918 0.0735 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 8.1680 0.0737 sec/batch
# Nearest to seven: one, eight, nine, three, six, five, four, zero,
# Nearest to war: political, union, united, army, after, during, states, forces,
# Nearest to so: the, to, a, as, of, should, are, some,
# Nearest to s: in, the, to, of, and, on, for, was,
# Nearest to there: the, of, in, to, and, not, is, it,
# Nearest to were: to, the, of, and, a, in, as, but,
# Nearest to first: the, was, in, of, and, on, s, time,
# Nearest to will: a, this, not, be, have, of, any, or,
# Nearest to road: three, city, one, home, who, named, at, from,
# Nearest to test: known, between, takes, what, and, so, focus, often,
# Nearest to woman: which, to, of, it, been, a, the, both,
# Nearest to ocean: south, north, sea, border, land, cities, coast, largest,
# Nearest to arts: in, including, longer, early, scientific, ground, source, rather,
# Nearest to except: the, of, and, with, to, this, other, over,
# Nearest to engine: their, respect, upon, increased, power, action, b, given,
# Nearest to mean: be, of, a, is, as, an, and, that,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 8.2548 0.0749 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 8.1496 0.0743 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 8.1193 0.0744 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 8.3156 0.0752 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.9606 0.0751 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.9336 0.0745 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 8.1751 0.0743 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.9086 0.0737 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.9325 0.0735 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.9921 0.0741 sec/batch
# Nearest to seven: six, nine, one, three, eight, four, two, five,
# Nearest to war: of, in, led, the, until, and, after, was,
# Nearest to so: that, this, which, are, to, a, in, all,
# Nearest to s: was, the, in, of, and, with, to, as,
# Nearest to there: are, that, which, is, the, for, this, as,
# Nearest to were: in, of, the, to, and, was, had, during,
# Nearest to first: in, the, of, s, with, by, to, since,
# Nearest to will: be, are, a, is, some, that, not, which,
# Nearest to road: at, major, nine, one, world, two, was, five,
# Nearest to test: are, have, called, an, any, their, or, both,
# Nearest to woman: born, in, new, life, live, all, who, s,
# Nearest to ocean: south, border, coast, sea, north, area, island, southern,
# Nearest to arts: here, only, how, regarding, including, are, longer, would,
# Nearest to except: a, as, be, which, to, with, there, of,
# Nearest to engine: show, if, some, usage, original, power, closely, for,
# Nearest to mean: generally, thus, all, with, much, if, for, used,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.9726 0.0753 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 7.6400 0.0745 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 7.6983 0.0754 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 7.8342 0.0756 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 7.8302 0.0752 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 7.7845 0.0748 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 8.0492 0.0750 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 7.4902 0.0752 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 7.7585 0.0742 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 7.8229 0.0755 sec/batch
# Nearest to seven: one, nine, six, five, eight, three, four, two,
# Nearest to war: was, until, united, forces, were, civil, under, during,
# Nearest to so: to, this, an, be, a, is, that, but,
# Nearest to s: the, in, and, for, of, on, at, a,
# Nearest to there: to, it, but, are, the, be, this, and,
# Nearest to were: and, on, in, of, the, until, to, only,
# Nearest to first: the, in, and, by, for, s, a, at,
# Nearest to will: be, that, to, are, is, or, there, it,
# Nearest to road: at, in, s, home, two, four, states, on,
# Nearest to test: not, are, between, different, or, where, there, that,
# Nearest to woman: at, as, s, in, by, with, and, was,
# Nearest to ocean: sea, coast, southern, country, border, north, western, island,
# Nearest to arts: own, period, in, starting, and, most, on, personal,
# Nearest to except: only, the, to, an, there, or, in, it,
# Nearest to engine: using, project, closely, program, on, slow, kind, provide,
# Nearest to mean: be, is, or, are, so, called, to, can,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 7.4421 0.0753 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 7.5602 0.0743 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 7.6084 0.0736 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 7.6433 0.0737 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 7.6586 0.0747 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 7.3725 0.0683 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 7.5028 0.0759 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 7.6300 0.0740 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 7.4281 0.0742 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 7.5025 0.0741 sec/batch
# Nearest to seven: one, nine, three, eight, six, five, two, four,
# Nearest to war: troops, was, army, of, by, after, the, in,
# Nearest to so: that, is, this, it, not, with, be, will,
# Nearest to s: a, of, and, in, the, with, to, by,
# Nearest to there: it, a, the, is, to, this, not, in,
# Nearest to were: to, the, a, and, in, was, of, by,
# Nearest to first: a, the, in, was, s, of, with, and,
# Nearest to will: this, is, not, use, be, or, can, even,
# Nearest to road: city, largest, zero, on, located, major, first, area,
# Nearest to test: of, a, to, an, but, with, the, be,
# Nearest to woman: a, years, in, at, of, live, s, who,
# Nearest to ocean: sea, south, island, coast, border, located, largest, mountain,
# Nearest to arts: art, training, references, at, into, including, much, s,
# Nearest to except: a, some, it, in, with, would, the, an,
# Nearest to engine: designed, performance, real, significantly, set, inc, project, than,
# Nearest to mean: can, is, means, be, such, not, we, used,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 7.4284 0.0751 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.1442 0.0735 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 7.2819 0.0738 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 7.3352 0.0739 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 7.2807 0.0740 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.0026 0.0742 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.9980 0.0741 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.0702 0.0748 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.1733 0.0739 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.2883 0.0738 sec/batch
# Nearest to seven: one, three, zero, eight, six, two, nine, four,
# Nearest to war: established, was, troops, after, during, former, states, state,
# Nearest to so: it, a, or, to, as, any, have, is,
# Nearest to s: on, the, and, to, of, by, with, in,
# Nearest to there: from, is, it, or, that, by, not, more,
# Nearest to were: of, the, in, its, and, to, by, was,
# Nearest to first: the, s, one, at, and, with, on, was,
# Nearest to will: be, a, or, this, is, have, more, to,
# Nearest to road: city, major, near, seven, world, largest, east, located,
# Nearest to test: of, a, and, the, by, in, with, between,
# Nearest to woman: live, years, her, life, birth, children, he, people,
# Nearest to ocean: coast, sea, island, land, north, pacific, south, mountain,
# Nearest to arts: art, in, history, still, another, education, early, with,
# Nearest to except: the, and, of, for, have, a, with, it,
# Nearest to engine: version, on, level, go, differ, open, least, designed,
# Nearest to mean: or, example, are, must, different, thought, so, a,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 7.0624 0.0752 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.0715 0.0743 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.0841 0.0743 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.2067 0.0737 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.0196 0.0741 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.8382 0.0743 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.9512 0.0739 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.9827 0.0742 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.8858 0.0734 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.0409 0.0741 sec/batch
# Nearest to seven: one, nine, six, eight, two, five, four, three,
# Nearest to war: united, ii, fell, germany, was, civil, world, until,
# Nearest to so: a, it, as, or, is, which, to, the,
# Nearest to s: the, by, in, and, on, of, was, to,
# Nearest to there: a, that, or, is, which, the, it, some,
# Nearest to were: of, in, and, the, was, to, as, been,
# Nearest to first: in, was, s, and, of, the, by, new,
# Nearest to will: a, for, is, have, or, these, so, some,
# Nearest to road: city, major, was, during, across, world, became, at,
# Nearest to test: other, a, known, in, of, when, for, time,
# Nearest to woman: life, children, years, her, she, live, his, who,
# Nearest to ocean: coast, north, pacific, island, area, sea, located, southern,
# Nearest to arts: articles, including, successful, s, art, from, new, and,
# Nearest to except: of, a, the, to, is, for, been, in,
# Nearest to engine: designed, internal, times, powered, replacement, control, design, version,
# Nearest to mean: is, if, different, be, case, or, called, can,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.7787 0.0754 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.6887 0.0738 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.9447 0.0738 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.8639 0.0741 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.7830 0.0735 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.8275 0.0737 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.9046 0.0740 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 6.5520 0.0741 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.6681 0.0733 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.6361 0.0744 sec/batch
# Nearest to seven: one, eight, six, nine, five, two, four, three,
# Nearest to war: troops, defeat, peace, army, independence, occupation, invasion, kingdom,
# Nearest to so: that, be, it, this, they, is, to, than,
# Nearest to s: was, the, and, in, of, first, as, on,
# Nearest to there: as, is, be, this, are, not, to, have,
# Nearest to were: of, the, and, to, was, in, by, from,
# Nearest to first: of, the, was, s, in, and, a, to,
# Nearest to will: it, be, more, is, that, used, however, these,
# Nearest to road: at, city, route, in, major, across, was, and,
# Nearest to test: this, for, have, however, be, is, all, when,
# Nearest to woman: live, life, children, his, s, she, her, years,
# Nearest to ocean: atlantic, south, coast, pacific, sea, southwest, land, region,
# Nearest to arts: art, and, school, when, including, became, took, articles,
# Nearest to except: of, in, a, most, some, the, this, more,
# Nearest to engine: internal, powered, unit, designed, directly, code, developing, improved,
# Nearest to mean: definition, is, means, defined, we, if, are, given,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.8106 0.0753 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.7607 0.0738 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.8493 0.0734 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.7152 0.0745 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 6.5335 0.0737 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.7989 0.0738 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 6.5961 0.0742 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 6.4744 0.0740 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 6.5134 0.0740 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.6766 0.0733 sec/batch
# Nearest to seven: one, eight, nine, six, five, four, two, three,
# Nearest to war: troops, defeat, peace, invasion, kingdom, civil, forces, germany,
# Nearest to so: this, a, or, more, as, be, is, it,
# Nearest to s: of, had, the, in, first, was, and, on,
# Nearest to there: the, to, an, with, a, more, many, has,
# Nearest to were: the, of, in, and, was, for, as, on,
# Nearest to first: s, was, had, the, and, year, in, by,
# Nearest to will: that, this, can, so, be, a, is, without,
# Nearest to road: area, city, major, at, across, two, s, urban,
# Nearest to test: are, the, as, an, at, all, much, number,
# Nearest to woman: life, children, man, wife, women, child, his, she,
# Nearest to ocean: atlantic, coast, south, pacific, sea, area, indian, land,
# Nearest to arts: training, art, master, has, school, notable, artists, teaching,
# Nearest to except: the, a, in, an, of, are, and, make,
# Nearest to engine: powered, using, typically, improved, appropriate, use, introduced, model,
# Nearest to mean: we, defined, is, can, function, given, means, therefore,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.6098 0.0748 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 6.5723 0.0488 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 6.5130 0.0735 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.5956 0.0743 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 6.4973 0.0741 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 6.5545 0.0740 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 6.5420 0.0734 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.3593 0.0745 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.3532 0.0736 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.3751 0.0739 sec/batch
# Nearest to seven: one, nine, eight, six, three, four, five, two,
# Nearest to war: troops, defeat, invasion, forces, union, allied, civil, state,
# Nearest to so: to, is, have, all, will, be, it, because,
# Nearest to s: and, was, the, by, in, of, on, with,
# Nearest to there: the, it, a, of, to, and, in, many,
# Nearest to were: the, of, in, and, was, by, with, at,
# Nearest to first: s, the, at, time, and, was, in, on,
# Nearest to will: be, so, that, this, is, because, to, all,
# Nearest to road: urban, located, city, area, part, its, near, years,
# Nearest to test: and, the, also, to, a, over, previous, in,
# Nearest to woman: children, she, s, life, people, men, was, well,
# Nearest to ocean: atlantic, coast, sea, area, south, island, western, pacific,
# Nearest to arts: art, university, on, training, including, school, received, world,
# Nearest to except: to, there, a, in, the, it, of, are,
# Nearest to engine: powered, model, models, speed, single, design, improved, designed,
# Nearest to mean: defined, can, is, values, if, example, function, then,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 6.4733 0.0760 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.1557 0.0745 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.1437 0.0743 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.2143 0.0746 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.2880 0.0744 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.4318 0.0734 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.2714 0.0736 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.2095 0.0743 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.2274 0.0745 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.3376 0.0741 sec/batch
# Nearest to seven: one, eight, nine, six, five, three, zero, four,
# Nearest to war: troops, army, leaders, forces, alliance, conflict, during, states,
# Nearest to so: that, this, it, the, or, a, of, be,
# Nearest to s: and, in, was, at, by, the, first, for,
# Nearest to there: the, are, a, of, which, that, is, it,
# Nearest to were: the, their, of, in, as, was, by, however,
# Nearest to first: was, s, last, the, at, in, were, one,
# Nearest to will: this, a, or, that, be, it, is, can,
# Nearest to road: near, city, located, south, town, east, three, area,
# Nearest to test: it, a, of, the, for, time, due, with,
# Nearest to woman: children, birth, life, man, years, death, live, her,
# Nearest to ocean: atlantic, coast, km, area, sea, northeast, southwest, coastal,
# Nearest to arts: new, education, received, school, in, art, history, training,
# Nearest to except: it, the, and, with, are, as, a, its,
# Nearest to engine: powered, fuel, designed, improved, features, improvements, range, efficient,
# Nearest to mean: therefore, is, different, given, we, all, if, be,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 6.3057 0.0752 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 6.0555 0.0738 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 6.1272 0.0744 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 6.1898 0.0742 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 6.0267 0.0744 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 6.2401 0.0738 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 6.1260 0.0747 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 5.8958 0.0741 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 6.1302 0.0739 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 6.2265 0.0734 sec/batch
# Nearest to seven: eight, nine, one, six, three, five, four, two,
# Nearest to war: army, troops, invasion, armed, forces, former, germany, until,
# Nearest to so: that, to, it, a, this, all, is, be,
# Nearest to s: in, the, by, of, on, one, at, and,
# Nearest to there: be, all, it, the, that, to, are, more,
# Nearest to were: the, and, of, in, by, as, at, with,
# Nearest to first: on, the, and, s, in, from, by, world,
# Nearest to will: is, be, to, or, a, which, that, have,
# Nearest to road: roads, city, located, train, near, zero, route, traffic,
# Nearest to test: other, for, to, will, such, all, would, an,
# ...
# Nearest to war: troops, army, armed, invasion, civil, fought, soldiers, treaty,
# Nearest to so: be, will, it, this, that, is, even, to,
# Nearest to s: and, was, the, in, on, new, of, also,
# Nearest to there: of, have, between, it, that, by, is, the,
# Nearest to were: was, the, by, to, had, far, however, later,
# Nearest to first: at, second, on, the, in, year, s, was,
# Nearest to will: be, that, this, even, to, so, because, it,
# Nearest to road: city, roads, opened, street, downtown, miles, longest, highway,
# Nearest to test: tests, tested, for, a, match, starting, on, also,
# Nearest to woman: she, her, children, life, death, man, men, birth,
# Nearest to ocean: atlantic, coast, sea, pacific, km, coastline, island, area,
# Nearest to arts: academy, art, university, education, martial, school, institute, fine,
# Nearest to except: some, have, it, to, which, all, with, and,
# Nearest to engine: engines, powered, speed, models, cylinder, designed, jet, reliability,
# Nearest to mean: equivalent, define, defined, geometric, arbitrary, sum, we, generalized,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.9425 0.0753 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.9021 0.0740 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.9350 0.0736 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.9875 0.0743 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.1224 0.0743 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.9586 0.0747 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.9829 0.0736 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.9880 0.0739 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.0799 0.0736 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.0571 0.0740 sec/batch
# Nearest to seven: one, eight, five, six, four, three, nine, zero,
# Nearest to war: army, troops, allied, germany, armed, civil, invasion, soviet,
# Nearest to so: it, is, this, be, if, a, these, will,
# Nearest to s: first, the, was, in, one, and, new, originally,
# Nearest to there: is, of, that, have, which, this, or, same,
# Nearest to were: the, and, however, from, to, their, before, with,
# Nearest to first: s, the, was, in, and, with, at, by,
# Nearest to will: this, be, can, or, if, that, only, because,
# Nearest to road: opened, located, downtown, city, park, street, near, railroad,
# Nearest to test: a, for, testing, with, model, time, tests, information,
# Nearest to woman: children, birth, her, she, parents, mother, herself, male,
# Nearest to ocean: atlantic, sea, coast, coastal, coastline, km, southeast, south,
# Nearest to arts: academy, art, school, received, education, graduate, alumni, students,
# Nearest to except: are, all, or, have, is, a, it, other,
# Nearest to engine: engines, powered, cylinder, fuel, spark, vehicles, speed, vehicle,
# Nearest to mean: is, difference, we, given, follows, example, defined, define,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.8929 0.0752 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.9507 0.0741 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.0337 0.0740 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.9015 0.0732 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.0665 0.0740 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.9321 0.0743 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.8515 0.0740 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.9830 0.0733 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.9979 0.0740 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.9196 0.0737 sec/batch
# Nearest to seven: six, eight, one, nine, three, four, five, two,
# Nearest to war: army, troops, former, peace, invasion, allied, after, until,
# Nearest to so: that, is, not, but, it, be, for, which,
# Nearest to s: was, of, by, as, first, with, in, on,
# Nearest to there: it, this, to, some, for, not, a, that,
# Nearest to were: was, during, the, in, had, by, out, until,
# Nearest to first: s, second, on, by, in, was, with, at,
# Nearest to will: that, because, be, a, such, only, often, is,
# Nearest to road: downtown, opened, miles, city, route, highway, railroad, roads,
# Nearest to test: testing, tests, challenge, improved, level, model, starting, tested,
# Nearest to woman: children, birth, male, she, female, her, life, girl,
# Nearest to ocean: atlantic, coastal, coast, situated, area, km, sea, pacific,
# Nearest to arts: academy, school, graduate, alumni, art, university, college, drama,
# Nearest to except: are, other, which, between, is, this, has, the,
# Nearest to engine: engines, powered, cylinder, speed, fitted, vehicle, speeds, load,
# Nearest to mean: is, above, way, note, e, means, we, values,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.9374 0.0748 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.9788 0.0739 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.8177 0.0736 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.8756 0.0738 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.8865 0.0741 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.9509 0.0732 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.9754 0.0741 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.0902 0.0737 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.0372 0.0734 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.8200 0.0739 sec/batch
# Nearest to seven: one, six, eight, nine, five, four, two, three,
# Nearest to war: army, troops, forces, defeat, during, armed, invasion, allied,
# Nearest to so: be, will, it, this, if, gives, therefore, can,
# Nearest to s: in, was, on, first, world, with, the, new,
# Nearest to there: this, have, is, to, be, are, some, however,
# Nearest to were: the, during, and, to, of, in, been, was,
# Nearest to first: s, the, was, in, by, one, on, at,
# Nearest to will: must, be, so, this, if, because, can, therefore,
# Nearest to road: miles, railroad, city, highway, opened, train, roads, mile,
# Nearest to test: tests, testing, provide, allow, maximum, tested, model, use,
# Nearest to woman: children, women, man, life, birth, herself, live, child,
# Nearest to ocean: atlantic, coast, pacific, narrow, southwest, km, sea, northeast,
# Nearest to arts: academy, art, students, school, alumni, master, student, university,
# Nearest to except: have, between, are, since, called, the, only, there,
# Nearest to engine: engines, powered, cylinder, speed, efficiency, fuel, speeds, jet,
# Nearest to mean: means, is, definition, equivalent, gives, variable, approximate, values,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.9516 0.0751 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.8907 0.0739 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.8421 0.0743 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.8042 0.0741 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.8656 0.0741 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.9687 0.0740 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.9273 0.0424 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.8521 0.0732 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.8495 0.0741 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.9239 0.0738 sec/batch
# Nearest to seven: one, eight, six, three, nine, five, four, two,
# Nearest to war: army, troops, battle, killed, soldiers, captured, defeat, forces,
# Nearest to so: be, will, way, an, if, make, same, because,
# Nearest to s: a, the, in, new, by, of, and, on,
# Nearest to there: to, is, as, it, the, and, for, but,
# Nearest to were: and, to, by, the, from, had, was, but,
# Nearest to first: second, s, by, a, on, the, was, in,
# Nearest to will: be, so, make, not, would, if, must, very,
# Nearest to road: miles, opened, roads, highway, traffic, city, station, street,
# Nearest to test: tests, tested, testing, flight, launch, achieved, at, since,
# Nearest to woman: children, birth, her, child, life, women, husband, herself,
# Nearest to ocean: atlantic, sea, islands, coast, southwest, south, km, island,
# Nearest to arts: martial, art, students, academy, school, schools, training, academic,
# Nearest to except: which, the, remain, a, there, is, same, an,
# Nearest to engine: engines, powered, speed, cylinder, jet, speeds, designed, plug,
# Nearest to mean: generalized, value, sum, e, values, is, defined, note,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.8305 0.0749 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.9383 0.0742 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.8113 0.0739 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.7563 0.0734 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.8065 0.0736 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.8688 0.0741 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.7766 0.0738 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.6717 0.0740 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.7332 0.0740 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.7430 0.0741 sec/batch
# Nearest to seven: eight, four, five, three, one, nine, six, zero,
# Nearest to war: troops, army, forces, armed, soldiers, invasion, revolutionary, fought,
# Nearest to so: be, it, not, will, that, same, or, a,
# Nearest to s: on, with, to, and, the, in, for, was,
# Nearest to there: it, the, of, that, to, have, some, is,
# Nearest to were: was, during, had, after, the, been, far, its,
# Nearest to first: second, the, at, a, time, s, for, was,
# Nearest to will: be, not, so, this, that, or, it, a,
# Nearest to road: highway, suburbs, city, downtown, miles, longest, station, railroad,
# Nearest to test: tests, match, starting, flight, at, competition, base, testing,
# Nearest to woman: birth, children, male, female, infant, adult, born, life,
# Nearest to ocean: atlantic, sea, coast, km, area, south, north, pacific,
# Nearest to arts: art, school, students, martial, academy, education, schools, college,
# Nearest to except: the, have, it, of, most, with, to, between,
# Nearest to engine: engines, powered, jet, speed, cylinder, designed, designs, models,
# Nearest to mean: value, function, is, represents, e, example, follows, we,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.8543 0.0746 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.7763 0.0746 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.7603 0.0743 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.7444 0.0740 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.8159 0.0736 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.9048 0.0740 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.7079 0.0741 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.7098 0.0736 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.7954 0.0740 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.7299 0.0741 sec/batch
# Nearest to seven: one, six, five, eight, three, nine, four, zero,
# Nearest to war: army, troops, invasion, peace, fought, allied, soldiers, commander,
# Nearest to so: it, be, can, a, is, will, means, that,
# Nearest to s: the, by, first, in, of, and, with, one,
# Nearest to there: is, be, for, a, has, are, other, of,
# Nearest to were: was, had, the, during, but, up, although, almost,
# Nearest to first: s, the, was, second, in, by, of, and,
# Nearest to will: be, can, that, so, or, a, this, out,
# Nearest to road: highway, railroad, route, miles, downtown, roads, opened, west,
# Nearest to test: tests, testing, for, an, each, information, designing, since,
# Nearest to woman: children, birth, mother, male, death, husband, she, female,
# Nearest to ocean: atlantic, coast, area, sea, pacific, coastal, km, north,
# Nearest to arts: school, college, university, academy, students, undergraduate, graduate, art,
# Nearest to except: be, is, that, a, are, to, into, of,
# Nearest to engine: engines, powered, cylinder, fuel, jet, fitted, vehicle, motor,
# Nearest to mean: is, thus, that, therefore, definition, we, number, values,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.7902 0.0754 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.7646 0.0740 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.6278 0.0731 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.7479 0.0740 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.8411 0.0744 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.7291 0.0739 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.7200 0.0744 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.7567 0.0738 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.6906 0.0737 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.6431 0.0742 sec/batch
# Nearest to seven: one, four, three, eight, five, nine, two, six,
# Nearest to war: invasion, army, troops, allied, soldiers, fought, allies, peace,
# Nearest to so: that, this, it, have, as, be, therefore, they,
# Nearest to s: in, by, at, first, the, was, and, a,
# Nearest to there: of, this, as, some, is, it, the, have,
# Nearest to were: to, the, and, however, their, was, by, in,
# Nearest to first: s, was, time, second, in, at, the, a,
# Nearest to will: a, could, if, make, this, be, because, can,
# Nearest to road: roads, highway, route, opened, railroad, downtown, rail, city,
# Nearest to test: tests, development, limited, testing, provide, for, changes, currently,
# Nearest to woman: born, male, birth, children, female, husband, herself, live,
# Nearest to ocean: atlantic, pacific, coast, sea, southeast, area, km, miles,
# Nearest to arts: school, academy, college, museum, university, art, students, faculty,
# Nearest to except: the, however, both, has, in, of, it, between,
# Nearest to engine: engines, powered, cylinder, vehicle, load, speeds, jet, efficiency,
# Nearest to mean: we, definition, above, this, constant, values, sum, can,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.6801 0.0750 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.7230 0.0740 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.7465 0.0745 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.8555 0.0734 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.9413 0.0737 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.6360 0.0742 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.7463 0.0735 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.6853 0.0729 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.5616 0.0752 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.6831 0.0744 sec/batch
# Nearest to seven: one, eight, six, four, nine, five, three, two,
# Nearest to war: army, troops, invasion, forces, allied, during, captured, peace,
# Nearest to so: be, it, this, that, a, will, can, to,
# Nearest to s: in, on, by, and, for, with, new, was,
# Nearest to there: is, the, to, it, and, have, as, other,
# Nearest to were: the, been, was, in, and, far, over, until,
# Nearest to first: was, second, in, after, by, on, last, new,
# Nearest to will: so, this, be, can, it, must, that, if,
# Nearest to road: highway, roads, traffic, street, opened, railroad, city, railway,
# Nearest to test: tests, testing, high, laboratory, nuclear, bomb, due, capability,
# Nearest to woman: life, male, children, birth, female, fertility, infant, sex,
# Nearest to ocean: atlantic, pacific, coast, islands, sea, location, south, island,
# Nearest to arts: martial, art, student, students, received, master, school, sports,
# Nearest to except: the, called, separate, in, however, there, since, only,
# Nearest to engine: engines, powered, jet, vehicle, motor, cylinder, load, designs,
# Nearest to mean: variable, if, sum, is, therefore, equivalent, generalized, arithmetic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.6786 0.0761 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.6889 0.0735 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
